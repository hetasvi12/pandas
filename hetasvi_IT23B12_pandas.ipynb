# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
# Out:
# 2.0.3

# %%
a=[1,2,3,4,5]
s1=pd.Series(a,index=["i1","i2","i3","i4","i5"]) 
print(s1)
# Out:
# i1    1
# i2    2
# i3    3
# i4    4
# i5    5
# dtype: int64

# %%
print((s1["i3"]))  #single data from the series
# Out:
# 3

# %%
keyVal={"AIML":4,"CCN":4,"WS":3,"CS":4}   #create series with key value pair
sKeyVal=pd.Series(keyVal)
print(sKeyVal)
# Out:
# AIML    4
# CCN     4
# WS      3
# CS      4
# dtype: int64

# %%
student={"subject":["aiml","ccn","ws","cs"],
          "marks":[90,90,80,85]}
sStud=pd.Series(student)
print(sStud)
# Out:
# subject    [aiml, ccn, ws, cs]
# marks         [90, 90, 80, 85]
# dtype: object

# %%
student={"subject":["aiml","ccn","ws","cs"], #data in form of row and column
          "marks":[90,90,80,85]}
dfStud=pd.DataFrame(student)
print(dfStud)
# Out:
#   subject  marks
# 0    aiml     90
# 1     ccn     90
# 2      ws     80
# 3      cs     85

# %%
print(dfStud.loc[0])   #fetch single data from the list
# Out:
# subject    aiml
# marks        90
# Name: 0, dtype: object

# %%
studData=pd.read_csv('C:\\Users\\Lenovo\\Desktop\\demp.csv')
print(studData)
# Out:
#    id     name         dob course   per
# 0   1  hetasvi  14-06-2003  mscit  75.0
# 1   2    mansi  25-12-2002  mscit  80.0
# 2   3   riddhi  14-04-2003  mscit  70.0
# 3   4     viya  17-10-2007    bca  80.0
# 4   5  dhruvil  23-07-2002     BE  70.0
# 5   6      abc  27-10-1908    NaN   NaN
# 6   7      xyz         NaN    NaN   NaN

# %%
print(studData.head())
# Out:
#    id     name         dob course per
# 0   1  hetasvi  14-06-2003  mscit  75
# 1   2    mansi  25-12-2002  mscit  80
# 2   3   riddhi  14-04-2003  mscit  70
# 3   4     viya  17-10-2007    bca  80
# 4   5  dhruvil  23-07-2002     BE  70

# %%
newstudent=studData.dropna()
print(newstudent)      #data will null is delete
# Out:
#    id     name         dob course              per
# 0   1  hetasvi  14-06-2003  mscit               75
# 1   2    mansi  25-12-2002  mscit               80
# 2   3   riddhi  14-04-2003  mscit               70
# 3   4     viya  17-10-2007    bca               80
# 4   5  dhruvil  23-07-2002     BE               70
# 5   6      abc  27-10-1908   3455  C:\Users\Lenovo

# %%
fillstud=studData.fillna(55)
print(fillstud)
# Out:
#    id     name         dob course   per
# 0   1  hetasvi  14-06-2003  mscit  75.0
# 1   2    mansi  25-12-2002  mscit  80.0
# 2   3   riddhi  14-04-2003  mscit  70.0
# 3   4     viya  17-10-2007    bca  80.0
# 4   5  dhruvil  23-07-2002     BE  70.0
# 5   6      abc  27-10-1908     55  55.0
# 6   7      xyz          55     55  55.0

# %%
new=studData["course"].fillna("mca")
print(new)
# Out:
# 0    mscit
# 1    mscit
# 2    mscit
# 3      bca
# 4       BE
# 5      mca
# 6      mca
# Name: course, dtype: object

# %%
print(studData.info())  #information from data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      7 non-null      int64
#  1   name    7 non-null      object
#  2   dob     6 non-null      object
#  3   course  5 non-null      object
#  4   per     5 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 412.0+ bytes
# None

# %%
studData["course"].fillna("mca",inplace=True)
print(studData)
# Out:
#    id     name         dob course   per
# 0   1  hetasvi  14-06-2003  mscit  75.0
# 1   2    mansi  25-12-2002  mscit  80.0
# 2   3   riddhi  14-04-2003  mscit  70.0
# 3   4     viya  17-10-2007    bca  80.0
# 4   5  dhruvil  23-07-2002     BE  70.0
# 5   6      abc  27-10-1908    mca   NaN
# 6   7      xyz         NaN    mca   NaN

# %%
studData["per"].fillna(55,inplace=True)  
print(studData)
# Out:
#    id     name         dob course   per
# 0   1  hetasvi  14-06-2003  mscit  75.0
# 1   2    mansi  25-12-2002  mscit  80.0
# 2   3   riddhi  14-04-2003  mscit  70.0
# 3   4     viya  17-10-2007    bca  80.0
# 4   5  dhruvil  23-07-2002     BE  70.0
# 5   6      abc  27-10-1908    mca  55.0
# 6   7      xyz         NaN    mca  55.0

# %%
mean=studData["per"].mean()
print(mean)
# Out:
# 69.28571428571429

# %%
median=studData["per"].median()
print(median)
# Out:
# 70.0

# %%
mode=studData["per"].mode()
print(mode[0])
# Out:
# 55.0

# %%
print(studData.tail())
# Out:
#    id     name         dob course   per
# 2   3   riddhi  14-04-2003  mscit  70.0
# 3   4     viya  17-10-2007    bca  80.0
# 4   5  dhruvil  23-07-2002     BE  70.0
# 5   6      abc  27-10-1908    mca  55.0
# 6   7      xyz         NaN    mca  55.0

# %%
fruitdata=pd.read_csv('C:\\Users\\Lenovo\\Desktop\\apple_quality.csv')
print(fruitdata)
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
mean=fruitdata["Size"].mean()   #find mean of trhe data
print(mean)
# Out:
# -0.50301462982675

# %%
median=fruitdata["Size"].median() #find median of the data
print(median)
# Out:
# -0.5137025125000001

# %%
mode=fruitdata["Size"].mode()  #find mode of data
print(mode[0])
# Out:
# -7.151703059

# %%
jobdata=pd.read_csv('C:\\Users\\Lenovo\\Desktop\\jobs_in_data.csv')
print(jobdata)
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
mode=jobdata["salary_in_usd"].mode()
print(mode)
# Out:
# 0    150000
# Name: salary_in_usd, dtype: int64

# %%
mean=jobdata["salary"].mean()
print(mean)
# Out:
# 149927.98129342598

# %%
median=jobdata["salary"].median()
print(median)
# Out:
# 143860.0

# %%
print(jobdata.tail())
# Out:
#       work_year                 job_title                  job_category  \
# 9350       2021           Data Specialist  Data Management and Strategy
# 9351       2020            Data Scientist     Data Science and Research
# 9352       2021  Principal Data Scientist     Data Science and Research
# 9353       2020            Data Scientist     Data Science and Research
# 9354       2020     Business Data Analyst                 Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 9350             USD  165000         165000      United States
# 9351             USD  412000         412000      United States
# 9352             USD  151000         151000      United States
# 9353             USD  105000         105000      United States
# 9354             USD  100000         100000      United States
#
#      experience_level employment_type work_setting company_location  \
# 9350           Senior       Full-time       Remote    United States
# ...

# %%
studData.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 studData.columns
#
# NameError: name 'studData' is not defined

# %%
game=pd.read_csv('C:\\Users\\Lenovo\\pokemon.csv')
print(game)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
game.columns  #show columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
game['total']=game['HP']+game['Attack']+game['Defense']  #total
game.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    143  45      49       49
# 1  2                Ivysaur  Grass  Poison    185  60      62       63
# 2  3               Venusaur  Grass  Poison    245  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    303  80     100      123
# 4  4             Charmander   Fire     NaN    134  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary         per         avg  \
# 0       65       65     45           1      False   47.666667   47.666667
# 1       80       80     60           1      False   61.666667   61.666667
# 2      100      100     80           1      False   81.666667   81.666667
# 3      122      120     80           1      False  101.000000  101.000000
# 4       60       50     65           1      False   44.666667   44.666667
#
#    total
# 0    143
# 1    185
# 2    245
# 3    303
# 4    134

# %%
game['per']=(game['total'])*100/300  #find percentage
game.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    143  45      49       49
# 1  2                Ivysaur  Grass  Poison    185  60      62       63
# 2  3               Venusaur  Grass  Poison    245  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    303  80     100      123
# 4  4             Charmander   Fire     NaN    134  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary         per         avg  \
# 0       65       65     45           1      False   47.666667   47.666667
# 1       80       80     60           1      False   61.666667   61.666667
# 2      100      100     80           1      False   81.666667   81.666667
# 3      122      120     80           1      False  101.000000  101.000000
# 4       60       50     65           1      False   44.666667   44.666667
#
#    total
# 0    143
# 1    185
# 2    245
# 3    303
# 4    134

# %%
game['avg']=(game['total'])/3   #avg 
game.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    143  45      49       49
# 1  2                Ivysaur  Grass  Poison    185  60      62       63
# 2  3               Venusaur  Grass  Poison    245  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    303  80     100      123
# 4  4             Charmander   Fire     NaN    134  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary         per         avg  \
# 0       65       65     45           1      False   47.666667   47.666667
# 1       80       80     60           1      False   61.666667   61.666667
# 2      100      100     80           1      False   81.666667   81.666667
# 3      122      120     80           1      False  101.000000  101.000000
# 4       60       50     65           1      False   44.666667   44.666667
#
#    total
# 0    143
# 1    185
# 2    245
# 3    303
# 4    134

# %%
game.sort_values(['per'],ascending=0)  #0 from dsecnding order
# Out:
#        #                     Name    Type 1  Type 2  Total   HP  Attack  \
# 424  383    GroudonPrimal Groudon    Ground    Fire    440  100     180
# 333  306        AggronMega Aggron     Steel     NaN    440   70     140
# 224  208      SteelixMega Steelix     Steel  Ground    430   75     125
# 268  248  TyranitarMega Tyranitar      Rock    Dark    414  100     164
# 313  289                  Slaking    Normal     NaN    410  150     160
# ..   ...                      ...       ...     ...    ...  ...     ...
# 139  129                 Magikarp     Water     NaN     85   20      10
# 303  280                    Ralts   Psychic   Fairy     78   28      25
# 186  172                    Pichu  Electric     NaN     75   20      40
# 68    63                     Abra   Psychic     NaN     60   25      20
# 381  349                   Feebas     Water     NaN     55   20      15
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary         per  \
# ...

# %%
game.sort_values(['per'],ascending=1)   #order form asecinding
# Out:
#        #                     Name    Type 1  Type 2  Total   HP  Attack  \
# 381  349                   Feebas     Water     NaN     55   20      15
# 68    63                     Abra   Psychic     NaN     60   25      20
# 186  172                    Pichu  Electric     NaN     75   20      40
# 303  280                    Ralts   Psychic   Fairy     78   28      25
# 139  129                 Magikarp     Water     NaN     85   20      10
# ..   ...                      ...       ...     ...    ...  ...     ...
# 313  289                  Slaking    Normal     NaN    410  150     160
# 268  248  TyranitarMega Tyranitar      Rock    Dark    414  100     164
# 224  208      SteelixMega Steelix     Steel  Ground    430   75     125
# 424  383    GroudonPrimal Groudon    Ground    Fire    440  100     180
# 333  306        AggronMega Aggron     Steel     NaN    440   70     140
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary         per  \
# ...

# %%
jobdata=pd.read_csv('C:\\Users\\Lenovo\\Desktop\\jobs_in_data.csv')
print(jobdata)
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
jobdata.sort_values(['work_year'],ascending=0)
# Out:
#       work_year                  job_title               job_category  \
# 0          2023       Data DevOps Engineer           Data Engineering
# 4976       2023         Research Scientist  Data Science and Research
# 4988       2023  Machine Learning Engineer    Machine Learning and AI
# 4987       2023  Machine Learning Engineer    Machine Learning and AI
# 4986       2023          Applied Scientist  Data Science and Research
# ...         ...                        ...                        ...
# 9149       2020          Big Data Engineer           Data Engineering
# 9152       2020             Data Scientist  Data Science and Research
# 9255       2020               Data Analyst              Data Analysis
# 9157       2020         Research Scientist  Data Science and Research
# 9354       2020      Business Data Analyst              Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
jobdata['avg']=(jobdata['total'])/2   #avg 
jobdata.head(5)
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size   total       avg
# ...

# %%
jobdata['total']=jobdata['salary']+jobdata['salary_in_usd']  #total
jobdata.head(5)
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size   total
# ...

# %%
jobdata['per']=(jobdata['total'])*100/2   #avg 
jobdata.head(5)
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size   total  \
# ...
